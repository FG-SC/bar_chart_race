# %% [markdown]
# # Intro
#
# This notebook follows the tutorial on https://www.dexplo.org/bar_chart_race/tutorial/

# %%
import pandas as pd
import bar_chart_race as bcr 

chains_tvl = pd.read_csv('chains.csv', index_col=0)
chains_tvl['Date']= pd.to_datetime(chains_tvl['Date'])
chains_tvl= chains_tvl.set_index('Date', drop=True)
chains_tvl
# Out:
#                 Bitlayer        Merlin     Rootstock      BSquared  \
# Date
# 2020-08-02           NaN           NaN           NaN           NaN
# 2020-08-03           NaN           NaN           NaN           NaN
# 2020-08-04           NaN           NaN           NaN           NaN
# 2020-08-05           NaN           NaN           NaN           NaN
# 2020-08-06           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2024-08-05  3.122676e+08  1.821353e+08  1.462183e+08  8.981536e+07
# 2024-08-06  3.349215e+08  1.944088e+08  1.566182e+08  1.190149e+08
# 2024-08-07  3.463804e+08  2.028108e+08  1.603087e+08  1.406194e+08
# 2024-08-08  3.470878e+08  2.041960e+08  1.640787e+08  1.422531e+08
# 2024-08-09  3.649967e+08  2.146721e+08  1.724037e+08  1.497787e+08
#
#                     CORE        Stacks     BounceBit          BOB  \
# Date
# 2020-08-02           NaN           NaN           NaN          NaN
# ...

# %%
chains_tvl.fillna(0, inplace=True)

# %%
# Documentation: https://pypi.org/project/bar-chart-race/
bcr.bar_chart_race(
    df=chains_tvl.loc['2024-01-01':],
    filename='btc_sidechains.mp4',
    orientation='h',
    sort='desc',
    n_bars=5,
    fixed_order=False,
    fixed_max=True,
    steps_per_period=4,
    interpolate_period=False,
    label_bars=True,
    bar_size=.95,
    period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
    period_fmt='%B %d, %Y',
    period_summary_func=lambda v, r: {'x': .99, 'y': .18,
                                      's': f'Overall TVL: {v.sum():,.0f}',
                                      'ha': 'right', 'size': 8, 'family': 'Courier New'},
    period_length=150, #half second?
    figsize=(12, 6),
    dpi=150,
    cmap='dark12',
    title='BTC sidechains TVL in USD (YTD)',
    bar_label_size=7,
    tick_label_size=7,
    scale='linear',
    writer=None,
    fig=None,
    bar_kwargs={'alpha': .7},
    filter_column_colors=False)
# Out:
# C:\Users\caoco\anaconda3\Lib\site-packages\bar_chart_race\_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# C:\Users\caoco\anaconda3\Lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\caoco\anaconda3\Lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# C:\Users\caoco\anaconda3\Lib\site-packages\bar_chart_race\_make_chart.py:226: UserWarning: Some of your columns never make an appearance in the animation. To reduce color repetition, set `filter_column_colors` to `True`
# ...
